# %%
from app.api_clients.nba_stats_api_client import NBAStatsAPIClient
import urllib.parse

# %%
date = "10/30/2013"
NBAStatsAPIClient.get_player_tracking_box_scores(measure_type="Passing", date_from=date, date_to=date)
# Out:
# {'resource': 'leaguedashptstats',
#  'parameters': {'PtMeasureType': 'Passing',
#   'PerMode': 'Totals',
#   'LeagueID': '00',
#   'Season': None,
#   'SeasonType': None,
#   'PORound': 0,
#   'Outcome': None,
#   'Location': None,
#   'Month': 0,
#   'SeasonSegment': None,
#   'DateFrom': '10/30/2013',
#   'DateTo': '10/30/2013',
#   'OpponentTeamID': 0,
#   'VsConference': None,
#   'VsDivision': None,
#   'TeamID': 0,
#   'Conference': None,
#   'Division': None,
#   'LastNGames': 0,
#   'GameScope': None,
#   'PlayerExperience': None,
#   'PlayerPosition': None,
#   'StarterBench': None,
#   'DraftYear': None,
#   'DraftPick': None,
#   'College': None,
#   'Country': None,
#   'Height': None,
#   'Weight': None,
#   'PlayerOrTeam': 'Player',
#   'ISTRound': None},
#  'resultSets': [{'name': 'LeagueDashPtStats',
#    'headers': ['PLAYER_ID',
#     'PLAYER_NAME',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'GP',
#     'W',
#     'L',
#     'MIN',
#     'PASSES_MADE',
# ...

# %%
date = "04/20/2025"
NBAStatsAPIClient.get_player_box_scores(measure_type="Base", season=None, season_type=None, period=0, playoff_round=0, date_from=date, date_to=date)
# Out:
# fetched https://stats.nba.com/stats/playergamelogs None None 0 Base
# {'resource': 'gamelogs',
#  'parameters': {'MeasureType': 'Base',
#   'PerMode': 'Totals',
#   'LeagueID': '00',
#   'SeasonYear': None,
#   'SeasonType': None,
#   'PORound': 0,
#   'TeamID': None,
#   'PlayerID': None,
#   'Outcome': None,
#   'Location': None,
#   'Month': 0,
#   'SeasonSegment': None,
#   'DateFrom': '04/20/2025',
#   'DateTo': '04/20/2025',
#   'OppTeamID': 0,
#   'VsConference': None,
#   'VsDivision': None,
#   'GameSegment': None,
#   'Period': 0,
#   'ShotClockRange': None,
#   'LastNGames': 0,
#   'ISTRound': None},
#  'resultSets': [{'name': 'PlayerGameLogs',
#    'headers': ['SEASON_YEAR',
#     'PLAYER_ID',
#     'PLAYER_NAME',
#     'NICKNAME',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'TEAM_NAME',
#     'GAME_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
# ...
